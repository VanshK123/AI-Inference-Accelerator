# %% [markdown]
# # ResNet-50 Inference Example

# %%
from accelerator import Accelerator
acc = Accelerator()
acc.init()

# %%
acc.load_model('resnet50_int8.bin')
result = acc.infer('image.jpg')
print(result)
